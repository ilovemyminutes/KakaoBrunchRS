# %%
import os
import sys
from tqdm import tqdm
from glob import glob
sys.path.insert(0, '../')

import pandas as pd
import numpy as np

import torch
from torch import nn

from tf_idf import get_tfidf
from load_data import load

# %%
metadata = load('metadata')
vocab = pd.read_csv('../raw/preprocessed/tag_vocab7000.csv')['tag'].tolist()

# %%
tfidf = get_tfidf(data=metadata, vocab=vocab)
# Out:
#   0%|          | 0/86037 [00:00<?, ?it/s]Build IDF...
#  11%|█         | 9171/86037 [03:29<46:57, 27.29it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1de39b35e4f4> in <module>()
# ----> 1 tfidf = get_tfidf(data=metadata, vocab=vocab)
#
# /content/drive/MyDrive/Colab Notebooks/KakaoBrunchRS/tf_idf.py in get_tfidf(data, vocab, indices)
#      33     for tag in tqdm(kwd_list):
#      34         if tag in vocab:
# ---> 35             idf.loc[0, tag] = np.log(num_docs / sum(batch['keyword_list'].apply(lambda x: tag in x)))
#      36
#      37     print('Build TF...')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /content/drive/MyDrive/Colab Notebooks/KakaoBrunchRS/tf_idf.py in <lambda>(x)
#      33     for tag in tqdm(kwd_list):
#      34         if tag in vocab:
# ---> 35             idf.loc[0, tag] = np.log(num_docs / sum(batch['keyword_list'].apply(lambda x: tag in x)))
#      36
#      37     print('Build TF...')
#
# KeyboardInterrupt:

# %%
vocab['tag'].tolist()
# Out:
# ['여행',
#  '영화',
#  '사랑',
#  '에세이',
#  '그림일기',
#  '생각',
#  '공감에세이',
#  '일상',
#  '글쓰기',
#  '감성에세이',
#  '인생',
#  '행복',
#  '연애',
#  '소설',
#  '드로잉',
#  '독서',
#  '육아',
#  '그림',
#  '마음',
#  '사진',
#  '리뷰',
#  '엄마',
#  '음악',
#  '스타트업',
#  '시',
#  '유럽여행',
#  '일러스트',
#  '이별',
#  '마케팅',
#  '고양이',
#  '디자인',
#  '영화리뷰',
#  '웹툰',
#  'IT',
#  '직장인',
#  '감성',
#  '일기',
#  '사람',
#  '결혼',
#  '친구',
#  '창업',
#  '회사',
#  '취업',
#  '교육',
#  '감성사진',
#  '퇴사',
#  '일본',
#  '건강',
#  '세계여행',
#  '해외여행',
#  '가족',
#  '커피',
#  '다이어트',
#  '성공',
#  '시간',
#  '직장',
#  '음식',
#  '운동',
#  '카페',
#  '책',
#  '맛집',
#  '문학',
#  '관계',
#  '가을',
#  '미국',
#  '심리',
#  '기억',
#  '영어',
#  '일상에세이',
#  '중국',
#  '철학',
#  '아이',
#  '제주',
#  '직장생활',
#  '일본여행',
#  '배낭여행',
#  '요리',
#  '이야기',
#  '육아일기',
#  '그림에세이',
#  '감정',
#  '공부',
#  '서평',
#  '인간관계',
#  '자기계발',
#  '책리뷰',
#  '부동산',
#  '추억',
#  '제주도',
#  '반려동물',
#  '강아지',
#  '뉴욕',
#  '역사',
#  '인문학',
#  '죽음',
#  '작가',
#  '예술',
#  '위로',
#  '겨울',
#  '아빠',
#  '인터뷰',
#  '브랜드',
#  '심리학',
#  '여행에세이',
#  '자존감',
#  '프랑스',
#  '반려견',
#  '꿈',
#  '공감',
#  '드라마',
#  '사회',
#  '아버지',
#  '습관',
#  '노래',
#  '바다',
#  '필사',
#  '유럽',
#  '그리움',
#  '인도',
#  '여름',
#  '투자',
#  '캘리그라피',
#  '파리',
#  '편지',
#  '감성글',
#  '하루',
#  '게임',
#  '인공지능',
#  '고민',
#  '만화',
#  '패션',
#  '브런치북',
#  '하늘',
#  '면접',
#  '재테크',
#  '사진에세이',
#  '학교',
#  '당신',
#  '국내여행',
#  '정치',
#  '독일',
#  '스페인',
#  '대화',
#  '페미니즘',
#  '시작',
#  '좋은글',
#  '오늘',
#  '삶',
#  '브런치',
#  '인간',
#  '청춘',
#  '여성',
#  '블록체인',
#  '자동차',
#  '호주',
#  '호텔',
#  '일상툰',
#  'UX',
#  '상처',
#  '여자',
#  '이탈리아',
#  '이직',
#  '베트남',
#  '공연',
#  '미술',
#  '미래',
#  '경제',
#  '서울',
#  '스마트폰',
#  '바람',
#  '맥주',
#  '세상',
#  '경영',
#  '콘텐츠',
#  '부모',
#  '글',
#  '문화',
#  '태국',
#  '영어공부',
#  '길고양이',
#  '전시',
#  '스트레스',
#  '광고',
#  '목표',
#  '건축',
#  '인연',
#  '변화',
#  '크리스마스',
#  '블로그',
#  '도쿄',
#  '선택',
#  '우리',
#  '봄',
#  '외로움',
#  '주식',
#  '디자이너',
#  '브런치X어라운드',
#  '성장',
#  '미국여행',
#  '아침',
#  '영국',
#  '런던',
#  '산책',
#  '선물',
#  '할머니',
#  '직업',
#  '애플',
#  '임신',
#  '감사',
#  '요가',
#  '어머니',
#  '자전거',
#  '눈물',
#  '레시피',
#  '소통',
#  '뮤지컬',
#  '나이',
#  '질문',
#  '공간',
#  '남자',
#  '부부',
#  '개발자',
#  '육아에세이',
#  '비트코인',
#  '어른',
#  '트렌드',
#  '아들',
#  '자유',
#  '기록',
#  '취미',
#  '서점',
#  '단편소설',
#  '페이스북',
#  '존재',
#  '새해',
#  '순간',
#  '클래식',
#  '인테리어',
#  '구글',
#  '용기',
#  '희망',
#  '불안',
#  '나무',
#  '브런치무비패스',
#  '아파트',
#  '사업',
#  '북리뷰',
#  '미술관',
#  '리더십',
#  '애니메이션',
#  '기획',
#  '우울',
#  '캐나다',
#  '언어',
#  '유튜브',
#  '대학',
#  '병원',
#  '워킹홀리데이',
#  '도전',
#  '수필',
#  '그림책',
#  '리더',
#  '유학',
#  '세계일주',
#  '아기',
#  '아프리카',
#  '여행기',
#  '자신',
#  '프로젝트',
#  '축구',
#  '세월호',
#  '회사생활',
#  '동물',
#  'SNS',
#  '홍콩',
#  '실패',
#  '모바일',
#  '시인',
#  '아빠육아',
#  '와인',
#  '비즈니스',
#  '경험',
#  '명상',
#  '새벽',
#  '브랜딩',
#  '도시',
#  '카메라',
#  '드론',
#  '우주',
#  '전원주택',
#  '축제',
#  '벚꽃',
#  '고양이사진',
#  '남편',
#  '사고',
#  '트래블라인싱가포르',
#  '혁신',
#  '슬픔',
#  '조직',
#  '기도',
#  '아이폰',
#  '대만',
#  '치앙마이',
#  '글귀',
#  '출판',
#  '계절',
#  '꽃',
#  '러시아',
#  '아내',
#  '워킹맘',
#  '국어',
#  '과학',
#  '정리',
#  '민주주의',
#  '제주여행',
#  '후회',
#  '자연',
#  '출산',
#  '노력',
#  '제주도여행',
#  '대통령',
#  '선생님',
#  '도서',
#  '명언',
#  '채용',
#  '의미',
#  '손글씨',
#  '그대',
#  '연극',
#  '한국',
#  '포토에세이',
#  '가치',
#  '버스',
#  '전략',
#  '생일',
#  '지하철',
#  '넷플릭스',
#  '열정',
#  '재즈',
#  '시집',
#  '전쟁',
#  '부자',
#  '남미여행',
#  '연인',
#  '데이터',
#  '뉴스',
#  '아이디어',
#  '직장인이야기',
#  '이해',
#  '개발',
#  '이사',
#  '취향',
#  '일러스트레이션',
#  '전시회',
#  '피아노',
#  '청년',
#  '책방',
#  '독립출판',
#  '심리상담',
#  '취준생',
#  '교토',
#  '자기소개서',
#  '미세먼지',
#  '현실',
#  '미디어',
#  '출근',
#  '방콕',
#  '계획',
#  '언론',
#  '팟캐스트',
#  '풍경',
#  '도서관',
#  'UI',
#  '강의',
#  '핀란드',
#  'AI',
#  '백수',
#  '믿음',
#  '이벤트',
#  '감성그림',
#  '자유여행',
#  '이름',
#  '포르투갈',
#  '그녀',
#  '바르셀로나',
#  '독후감',
#  '날씨',
#  '영어회화',
#  '동화',
#  '스웨덴',
#  '만남',
#  '산티아고',
#  '놀이',
#  '힐링',
#  '트럼프',
#  '고백',
#  '쇼핑',
#  '단편',
#  '산티아고순례길',
#  '출간',
#  '두려움',
#  '고통',
#  '싱가포르',
#  '휴가',
#  '주말',
#  '마블',
#  '자소서',
#  '행동',
#  '디지털노마드',
#  '진로',
#  '아픔',
#  '초등학교',
#  '프라하',
#  '로마',
#  '비',
#  '신입사원',
#  '휴식',
#  '노동',
#  '자본주의',
#  '비행기',
#  '캠핑',
#  '수업',
#  '군대',
#  '아마존',
#  '오사카',
#  '상담',
#  '이민',
#  '자신감',
#  '문장',
#  '부산',
#  '책소개',
#  '북한',
#  '뉴욕여행',
#  '커뮤니케이션',
#  '발리',
#  '환경',
#  '인사',
#  '걱정',
#  '카카오',
#  '운명',
#  '우울증',
#  '모임',
#  '명절',
#  '소리',
#  '해외생활',
#  '짝사랑',
#  '수학',
#  '기분',
#  '책읽기',
#  '가족여행',
#  '이유',
#  '손그림',
#  '인도여행',
#  '산문',
#  '박근혜',
#  '야구',
#  '타인',
#  '욕망',
#  '브런치X볼드저널',
#  '플랫폼',
#  '배우',
#  '한강',
#  '퇴근',
#  'SF',
#  '청소',
#  '남자친구',
#  '표현',
#  '일상드로잉',
#  '독서모임',
#  '주식투자',
#  '스타벅스',
#  '식물',
#  '강연',
#  '기자',
#  '고독',
#  '수능',
#  '종교',
#  '진실',
#  '육아이야기',
#  '다이어리',
#  '다큐멘터리',
#  '시험',
#  '가죽공예',
#  '베를린',
#  '빅데이터',
#  '오키나와',
#  '단상',
#  '가상화폐',
#  '뉴질랜드',
#  '조직문화',
#  '공항',
#  '여유',
#  '생활',
#  '캄보디아',
#  '해외취업',
#  '결혼식',
#  '스쿠버다이빙',
#  '성격',
#  '여행사진',
#  '교사',
#  '인턴',
#  '아이돌',
#  '공포',
#  '하와이',
#  '남미',
#  '거짓말',
#  '추석',
#  '분노',
#  '감기',
#  '스위스',
#  '향기',
#  '얼굴',
#  '과거',
#  '데이트',
#  '가사',
#  '프리랜서',
#  '마케터',
#  '스타일',
#  '상상',
#  '아이슬란드',
#  '공무원',
#  '방송',
#  '선거',
#  '로봇',
#  '필름사진',
#  '술',
#  '프로그래밍',
#  '스포츠',
#  '자아',
#  '인스타그램',
#  '매일',
#  '여행정보',
#  '욕심',
#  '안드로이드',
#  '라오스',
#  '진심',
#  '길냥이',
#  '고향',
#  '네덜란드',
#  '어린이집',
#  '후기',
#  '소비',
#  '업무',
#  '시선',
#  '로맨스',
#  '독서노트',
#  '영업',
#  '연재소설',
#  '쿠바',
#  '일',
#  '집밥',
#  '화장품',
#  '소개팅',
#  '아일랜드',
#  '사막',
#  '스트레칭',
#  '나',
#  '이슈',
#  '세월',
#  '동네',
#  '책이야기',
#  '몽골',
#  '이혼',
#  '단편영화',
#  '시간관리',
#  '알바',
#  '할아버지',
#  '처음',
#  '미니멀라이프',
#  '편의점',
#  '하나님',
#  '무라카미하루키',
#  '후쿠오카',
#  '일상기록',
#  '지혜',
#  '힙합',
#  '스릴러',
#  '터키',
#  '사회생활',
#  '라디오',
#  '라라랜드',
#  '네팔',
#  '긍정',
#  '첫사랑',
#  '보안',
#  '목소리',
#  '금융',
#  '시골',
#  '포기',
#  '브라질',
#  '기독교',
#  '응원',
#  '기업',
#  '서비스',
#  '문제',
#  '한국영화',
#  '웃음',
#  '노인',
#  '중국어',
#  '육아휴직',
#  '우리말',
#  '방법',
#  '멕시코',
#  '등산',
#  '깨달음',
#  '간호사',
#  '문재인',
#  '정의',
#  '생명',
#  '구름',
#  '홍콩여행',
#  '경찰',
#  '자전거여행',
#  '라이프스타일',
#  '북유럽',
#  '상사',
#  '신혼여행',
#  '폭력',
#  '스케치',
#  '피부',
#  '기차',
#  '캘리그래피',
#  '번역',
#  '수영',
#  '영화추천',
#  '미니멀리즘',
#  '차별',
#  '집짓기',
#  '스페인여행',
#  '인권',
#  '인터넷',
#  '가방',
#  '의사',
#  '마지막',
#  '크로아티아',
#  '치유',
#  '반려묘',
#  '창의성',
#  '칭찬',
#  '영혼',
#  '말',
#  '덴마크',
#  '승무원',
#  '네이버',
#  '실수',
#  '중년',
#  '수채화',
#  '메모',
#  '샌프란시스코',
#  '돈',
#  '대기업',
#  '다짐',
#  '마을',
#  '햇살',
#  '약속',
#  '변호사',
#  '신용카드',
#  '박물관',
#  '음악에세이',
#  '자녀교육',
#  '사진일기',
#  '청소년',
#  '그리스',
#  '교회',
#  '준비',
#  '피렌체',
#  '판타지',
#  '어둠',
#  '독서일기',
#  '올림픽',
#  '야근',
#  '리스본',
#  '디저트',
#  '현대미술',
#  '추천도서',
#  '세계',
#  '대한민국',
#  '프로야구',
#  '분석',
#  '집',
#  '거리',
#  '우산',
#  'MBC',
#  '태도',
#  '커리어',
#  '기다림',
#  '트레킹',
#  '대학원',
#  '디즈니',
#  '텃밭',
#  '아르바이트',
#  '기획자',
#  '눈',
#  '월요일',
#  '배움',
#  '발레',
#  '독립',
#  '홋카이도',
#  '한글',
#  '고객',
#  '농사',
#  '목조주택',
#  '편견',
#  '결혼생활',
#  '자취',
#  '코칭',
#  '칼럼',
#  '문화예술',
#  '평화',
#  '내일',
#  '대학생',
#  '밤',
#  '용서',
#  '꼰대',
#  '우정',
#  '앨범',
#  '사춘기',
#  '버킷리스트',
#  '사색',
#  '운전',
#  '해외',
#  '인문',
#  '오스트리아',
#  '이력서',
#  '소년',
#  '사과',
#  '브런치X빨강머리앤',
#  '페미니스트',
#  '보험',
#  '인도네시아',
#  '배려',
#  '기술',
#  '실리콘밸리',
#  '채식',
#  '훈련',
#  '파도',
#  '서울시',
#  '히말라야',
#  '봄꽃',
#  '여자친구',
#  '꿀팁',
#  '코딩',
#  '창작',
#  '책임',
#  '소녀',
#  '시장',
#  '산업혁명',
#  '일자리',
#  '단풍',
#  '연말',
#  '핀테크',
#  '관심',
#  '여름휴가',
#  '택시',
#  '동네서점',
#  '고전',
#  '레스토랑',
#  '장애인',
#  '외국어',
#  '체코',
#  '전화',
#  '담배',
#  '단어',
#  '시사',
#  '모로코',
#  '미얀마',
#  '골목',
#  '귀농',
#  '설렘',
#  '미드',
#  '에어비앤비',
#  '매거진',
#  '독서법',
#  '무기력',
#  '느낌',
#  '기적',
#  '중국여행',
#  '정원',
#  '월드컵',
#  '결혼준비',
#  '하루키',
#  '독립영화',
#  '식당',
#  '신혼일기',
#  '정체성',
#  '골프',
#  '본질',
#  '집사',
#  '기회',
#  '수술',
#  '심리치료',
#  '촛불',
#  '가슴',
#  '아프리카여행',
#  '은행',
#  '신혼부부',
#  '오피스텔',
#  '크루즈',
#  '제주살이',
#  '라면',
#  '저녁',
#  '장미',
#  '출장',
#  '노무현',
#  '공동체',
#  '순례길',
#  '노르웨이',
#  '카툰',
#  '하노이',
#  '1인기업',
#  '신뢰',
#  '침묵',
#  '음악리뷰',
#  '경주',
#  '온디맨드',
#  '영화후기',
#  '중독',
#  '일본영화',
#  '고등학교',
#  '사랑이야기',
#  '영상',
#  '장난감',
#  '수면',
#  '심리치유',
#  '지식',
#  '말씀',
#  '페루',
#  '봄날',
#  '연애소설',
#  '집중',
#  '재미',
#  '지구',
#  '관점',
#  '이웃집유부녀',
#  '고흐',
#  '4차산업혁명',
#  '착각',
#  'TV',
#  '냄새',
#  '조언',
#  '평가',
#  '소셜미디어',
#  '라이프',
#  '잡지',
#  '동기부여',
#  '노을',
#  '쓰레기',
#  '졸업',
#  '공원',
#  '에너지',
#  '공자',
#  '내면',
#  'VR',
#  '성경',
#  '혼자여행',
#  '회사원',
#  '낙엽',
#  '위안부',
#  '과일',
#  '화가',
#  '그림자',
#  '막걸리',
#  '대출',
#  '여행지',
#  '베스트셀러',
#  '추천',
#  '범죄',
#  '실천',
#  '갈등',
#  '연습',
#  '니체',
#  '비밀',
#  '흔적',
#  '인종차별',
#  '향수',
#  '마라톤',
#  '이더리움',
#  '동화책',
#  '회의',
#  '기차여행',
#  '공부법',
#  '소주',
#  '강사',
#  '스피치',
#  '유기견',
#  '캐릭터',
#  '장애',
#  '발표',
#  '의지',
#  '유치원',
#  '취업준비',
#  '폴란드',
#  '필리핀',
#  '서핑',
#  '동생',
#  '어린이',
#  '간호사일기',
#  '존중',
#  '교환학생',
#  '야경',
#  '게스트하우스',
#  '안녕',
#  '디지털',
#  '월급',
#  '홍보',
#  '대선',
#  '예술가',
#  '관광',
#  '오페라',
#  '고도',
#  '인정',
#  '대만여행',
#  '경쟁',
#  '가난',
#  '일요일',
#  '커뮤니티',
#  '신발',
#  '결정',
#  '화장실',
#  '난민',
#  '식사',
#  '쇼핑몰',
#  '컴퓨터',
#  '교통사고',
#  '경매',
#  '분양',
#  '신화',
#  '하루하루',
#  '근육',
#  '뮌헨',
#  '말레이시아',
#  '떡볶이',
#  '매력',
#  '논어',
#  '다이빙',
#  '콘서트',
#  '페스티벌',
#  '달',
#  '전자책',
#  '프레젠테이션',
#  '일상이야기',
#  '치킨',
#  '커플',
#  '윤동주',
#  '정신',
#  '환자',
#  '입양',
#  '며느리',
#  '가상현실',
#  'CEO',
#  '길',
#  '유시민',
#  '첫눈',
#  '홍상수',
#  '발견',
#  '시드니',
#  '기대',
#  '학원',
#  '현재',
#  '공유',
#  '연재',
#  '강원도',
#  '예능',
#  '성찰',
#  '암호화폐',
#  '관찰',
#  '실화',
#  '영화이야기',
#  '학습',
#  '강릉',
#  '통증',
#  '외모',
#  '재능',
#  '사무실',
#  '세금',
#  '신문',
#  '공포영화',
#  '의식',
#  '투표',
#  '일러스트레이터',
#  '안부',
#  '협상',
#  '포르투',
#  '삿포로',
#  '화분',
#  '까미노',
#  '공유경제',
#  '생각정리',
#  '에버노트',
#  '어학연수',
#  '여성혐오',
#  '퇴직',
#  '감동',
#  '동영상',
#  '필름',
#  '크라우드펀딩',
#  '출근길',
#  '거울',
#  '파티',
#  '대학생활',
#  ...]
